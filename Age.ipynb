# %% [markdown]
# Analyzing persons of different age groups in a random city

# %% [markdown]
# here we are analyzing count of 65+ age old citizens in Kolhapur city.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
age = "Dataset/census_age.csv"

# %%
df = pd.read_csv(age)

# %%
print(df.shape)
# Out:
# (13509, 15)

# %%
df.isnull().any()
# Out:
# Unnamed: 0       False
# Table Name       False
# State Code       False
# District Code    False
# Area Name        False
# Age Group        False
# Total Persons    False
# Total Males      False
# Total Females    False
# Rural Persons    False
# Rural Males      False
# Rural Females    False
# Urban Persons    False
# Urban Males      False
# Urban Females    False
# dtype: bool

# %%
c = df.groupby('State Code')
c

# %%
MH = c.get_group(27)

# %%
MH
# Out:
#       Unnamed: 0 Table Name  State Code  District Code  \
# 513          513      C4114          27              0
# 514          514      C4114          27              0
# 515          515      C4114          27              0
# 516          516      C4114          27              0
# 517          517      C4114          27              0
# ...          ...        ...         ...            ...
# 7196        7196      C4114          27            531
# 7197        7197      C4114          27            531
# 7198        7198      C4114          27            531
# 7199        7199      C4114          27            531
# 7200        7200      C4114          27            531
#
#                      Area Name       Age Group  Total Persons  Total Males  \
# 513   State - MAHARASHTRA (27)        All ages      112374333     58243056
# 514   State - MAHARASHTRA (27)             0-4        9362026      4939629
# 515   State - MAHARASHTRA (27)             5-9        9820654      5178177
# ...

# %% [markdown]
# This is data of Maharashtra

# %%
Ds = MH.groupby('District Code')
Ds

# %%
KP = Ds.get_group(530)

# %% [markdown]
# For example take the data of Kolhapur city.

# %%
KP
# Out:
#       Unnamed: 0 Table Name  State Code  District Code  \
# 7163        7163      C4114          27            530
# 7164        7164      C4114          27            530
# 7165        7165      C4114          27            530
# 7166        7166      C4114          27            530
# 7167        7167      C4114          27            530
# 7168        7168      C4114          27            530
# 7169        7169      C4114          27            530
# 7170        7170      C4114          27            530
# 7171        7171      C4114          27            530
# 7172        7172      C4114          27            530
# 7173        7173      C4114          27            530
# 7174        7174      C4114          27            530
# 7175        7175      C4114          27            530
# 7176        7176      C4114          27            530
# 7177        7177      C4114          27            530
# 7178        7178      C4114          27            530
# ...

# %% [markdown]
# Total data required for project

# %% [markdown]
# Thus we get Total Count of persons according to age from Kolhapur city
